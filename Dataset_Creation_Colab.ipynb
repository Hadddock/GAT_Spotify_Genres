# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import spotipy
import json
from collections import Counter
from spotipy.oauth2 import SpotifyClientCredentials
import pickle
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse import lil_matrix

# %% [markdown]
# ## Spotify Credentials
# Set environment variables for your Spotify credentials

# %%
cid = os.environ.get("SPOTIPY_CLIENT_ID")
secret = os.environ.get("SPOTIPY_CLIENT_SECRET")
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Collect information from Spotify Million Playlist Dataset
#
# Download dataset from: https://www.aicrowd.com/challenges/spotify-million-playlist-dataset-challenge

# %%
tracks_info = {}#key = track uri, value = list of information about the track
tracks_neighbors = {}#key = track uri, value = Counter of tracks neighbors
track_playlist_count = {} #key = track uri, value = total playlist appearences

with open("data/mpd.slice.0-999.json", "r") as read_file:
    data = json.load(read_file)
for playlist in data.get('playlists'):
    playlist_track_uris = set() #all track uris appearing in this playlist
    for track in playlist.get('tracks'):
        track_info = []
        track_uri = track.get("track_uri")
        if not track_uri in tracks_info.keys():#only retrive track info once
            tracks_info[track_uri] = [
                track.get('track_name'),
                track.get("artist_uri"),
                track.get("artist_name"),
                track.get("album_uri"),
                track.get("album_name")
                ]
        if not track_uri in playlist_track_uris:#do not count multiple entries of same song in playlist twoards track_playlist_count
            if not track_uri in track_playlist_count.keys():#keep track of total playlist occurences
                track_playlist_count[track_uri] = 0
            track_playlist_count[track_uri] += 1
        playlist_track_uris.add(track_uri)
        
    for track in playlist.get('tracks'):#update neighbors for each track in the playlist
        track_uri = track.get("track_uri")
        if not track_uri in tracks_neighbors.keys():
            tracks_neighbors[track_uri] = Counter()
        tracks_neighbors[track_uri].update(playlist_track_uris)

# %% [markdown]
# ## Get track features from Spotify api
# Spotify limits retriving track info to 100 tracks per query

# %%
track_features = []
total_track_count =len(tracks_info.keys())
for i in range(0, total_track_count, 100):
    end_index = min(i + 100, total_track_count)
    track_features.extend(spotify.audio_features(list(tracks_info.keys())[i:end_index]))

# %% [markdown]
# ## Create dataframe

# %%
df = pd.DataFrame.from_dict(data=tracks_info, orient = 'index', columns=['title', 'artist uri', 'artist', 'album uri', 'album title'])
df.reset_index(inplace=True)
df.rename(columns={'index': 'uri'}, inplace=True)
df['total playlist appearences'] = track_playlist_count.values()
df['neighboring tracks'] = tracks_neighbors.values()
df = pd.merge(df, pd.DataFrame.from_dict(data=track_features), on="uri")

# %% [markdown]
# ## Pickle Helper Functions

# %%
def pickle_object(output_file_name, object):
    dbfile = open(output_file_name, 'ab')   
    pickle.dump(object, dbfile)                     
    dbfile.close()
    
def unpickle_object(pickle_file_name):
    with open('track_dataframe.pickle', "rb") as input_file:
        unpickled_object = pickle.load(input_file)
    return unpickled_object

# %% [markdown]
# pickle the dataframe

# %%
pickle_object('track_dataframe.pickle',df)

# %% [markdown]
# load the dataframe

# %%
df = unpickle_object('track_dataframe.pickle')

# %%
display(df)
# Out:
#                                         uri  \
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1      spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2      spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3      spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4      spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                                     ...
# 34438  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 34439  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 34440  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 34441  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 34442  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
#                                               title  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 34438                                  I Don't Know
# 34439                                    The Answer
# 34440                                         25.22
# 34441                                  Good Feeling
# 34442  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   artist uri             artist  \
# 0      spotify:artist:2wIVse2owClT7go1WT98tk      Missy Elliott
# 1      spotify:artist:26dSoYclwsYLMAKD3tpOr4     Britney Spears
# 2      spotify:artist:6vWDO969PvNqNYHIOW5v0m            Beyoncé
# 3      spotify:artist:31TPClRtHm23RisEBtV3X7  Justin Timberlake
# 4      spotify:artist:5EvFsr3kj42KNv97ZEnqij             Shaggy
# ...                                      ...                ...
# 34438  spotify:artist:5HCypjplgh5uQezvBpOfXN              Jon D
# 34439  spotify:artist:0sHN89qak07mnug3LVVjzP          Big Words
# 34440  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk       Allan Rayman
# 34441  spotify:artist:77bNdkKYBBmc30CisCA6tE          Jon Jason
# 34442  spotify:artist:6Xa4nbrSTfbioA4lLShbjh           Grizfolk
#
#                                   album uri  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1      spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2      spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3      spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4      spotify:album:6NmFmPX56pcLBOFMhIiKvF
# ...                                     ...
# 34438  spotify:album:2KEQtuVl1cYsTYtVRUrNVi
# 34439  spotify:album:5jrsRHRAmetu5e7RRBoxj7
# 34440  spotify:album:3CbNgBzI7r9o0F6VjH9sTY
# 34441  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP
# 34442  spotify:album:7D6Y19tjm4DQNch39FeWpO
#
#                                         album title  \
# 0                                      The Cookbook
# 1                                       In The Zone
# 2      Dangerously In Love (Alben für die Ewigkeit)
# 3                                         Justified
# 4                                          Hot Shot
# ...                                             ...
# 34438                                         Roots
# 34439            Hollywood, a Beautiful Coincidence
# 34440                                  Roadhouse 01
# 34441                                  Good Feeling
# 34442                                  Cosmic Angel
#
#        total playlist appearences  \
# 0                               6
# 1                              13
# 2                              27
# 3                               9
# 4                              25
# ...                           ...
# 34438                           1
# 34439                           1
# 34440                           1
# 34441                           1
# 34442                           1
#
#                                       neighboring tracks  danceability  \
# 0      {'spotify:track:0XUfyU2QviPAs6bxSpXYG4': 4, 's...         0.904
# 1      {'spotify:track:0XUfyU2QviPAs6bxSpXYG4': 5, 's...         0.774
# 2      {'spotify:track:0XUfyU2QviPAs6bxSpXYG4': 11, '...         0.664
# 3      {'spotify:track:0XUfyU2QviPAs6bxSpXYG4': 5, 's...         0.892
# 4      {'spotify:track:0XUfyU2QviPAs6bxSpXYG4': 7, 's...         0.853
# ...                                                  ...           ...
# 34438  {'spotify:track:4gFxywaJejXWxo0NjlWzgg': 1, 's...         0.669
# 34439  {'spotify:track:4gFxywaJejXWxo0NjlWzgg': 1, 's...         0.493
# 34440  {'spotify:track:4gFxywaJejXWxo0NjlWzgg': 1, 's...         0.702
# 34441  {'spotify:track:4gFxywaJejXWxo0NjlWzgg': 1, 's...         0.509
# 34442  {'spotify:track:4gFxywaJejXWxo0NjlWzgg': 1, 's...         0.639
#
#        energy  ...  instrumentalness  liveness  valence    tempo  \
# 0       0.813  ...          0.006970    0.0471    0.810  125.461
# 1       0.838  ...          0.025000    0.2420    0.924  143.040
# 2       0.758  ...          0.000000    0.0598    0.701   99.259
# 3       0.714  ...          0.000234    0.0521    0.817  100.972
# 4       0.606  ...          0.000000    0.3130    0.654   94.759
# ...       ...  ...               ...       ...      ...      ...
# 34438   0.228  ...          0.065000    0.0944    0.402   83.024
# 34439   0.727  ...          0.000000    0.1290    0.289   73.259
# 34440   0.524  ...          0.055300    0.2980    0.265  140.089
# 34441   0.286  ...          0.000012    0.1310    0.259  121.633
# 34442   0.461  ...          0.000057    0.1120    0.264  117.583
#
#                  type                      id  \
# 0      audio_features  0UaMYEvWZi0ZqiDOoHU3YI
# 1      audio_features  6I9VzXrHxO9rA9A5euc8Ak
# 2      audio_features  0WqIKmW4BTrj3eJFmnCKMv
# 3      audio_features  1AWQoqb9bSvzTjaLralEkT
# 4      audio_features  1lzr43nnXAijIGYnCT8M8H
# ...               ...                     ...
# 34438  audio_features  3uCHI1gfOUL5j5swEh0TcH
# 34439  audio_features  0P1oO2gREMYUCoOkzYAyFu
# 34440  audio_features  2oM4BuruDnEvk59IvIXCwn
# 34441  audio_features  4Ri5TTUgjM96tbQZd5Ua7V
# 34442  audio_features  5RVuBrXVLptAEbGJdSDzL5
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 1      https://api.spotify.com/v1/tracks/6I9VzXrHxO9r...
# 2      https://api.spotify.com/v1/tracks/0WqIKmW4BTrj...
# 3      https://api.spotify.com/v1/tracks/1AWQoqb9bSvz...
# 4      https://api.spotify.com/v1/tracks/1lzr43nnXAij...
# ...                                                  ...
# 34438  https://api.spotify.com/v1/tracks/3uCHI1gfOUL5...
# 34439  https://api.spotify.com/v1/tracks/0P1oO2gREMYU...
# 34440  https://api.spotify.com/v1/tracks/2oM4BuruDnEv...
# 34441  https://api.spotify.com/v1/tracks/4Ri5TTUgjM96...
# 34442  https://api.spotify.com/v1/tracks/5RVuBrXVLptA...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0UaM...       226864
# 1      https://api.spotify.com/v1/audio-analysis/6I9V...       198800
# 2      https://api.spotify.com/v1/audio-analysis/0WqI...       235933
# 3      https://api.spotify.com/v1/audio-analysis/1AWQ...       267267
# 4      https://api.spotify.com/v1/audio-analysis/1lzr...       227600
# ...                                                  ...          ...
# 34438  https://api.spotify.com/v1/audio-analysis/3uCH...       189184
# 34439  https://api.spotify.com/v1/audio-analysis/0P1o...       263680
# 34440  https://api.spotify.com/v1/audio-analysis/2oM4...       189213
# 34441  https://api.spotify.com/v1/audio-analysis/4Ri5...       194720
# 34442  https://api.spotify.com/v1/audio-analysis/5RVu...       257195
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 34438              4
# 34439              4
# 34440              4
# 34441              4
# 34442              4
#
# [34443 rows x 25 columns]
